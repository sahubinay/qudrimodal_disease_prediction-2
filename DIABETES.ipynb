# %% [markdown]
# <a href="https://colab.research.google.com/github/sahubinay/qudrimodal_disease_prediction-2/blob/main/DIABETES.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv("/content/diabetes_risk_prediction_dataset.csv")
data.head()
# Out:
#    Age Gender Polyuria Polydipsia sudden weight loss weakness Polyphagia  \
# 0   40   Male       No        Yes                 No      Yes         No
# 1   58   Male       No         No                 No      Yes         No
# 2   41   Male      Yes         No                 No      Yes        Yes
# 3   45   Male       No         No                Yes      Yes        Yes
# 4   60   Male      Yes        Yes                Yes      Yes        Yes
#
#   Genital thrush visual blurring Itching Irritability delayed healing  \
# 0             No              No     Yes           No             Yes
# 1             No             Yes      No           No              No
# 2             No              No     Yes           No             Yes
# 3            Yes              No     Yes           No             Yes
# 4             No             Yes     Yes          Yes             Yes
#
#   partial paresis muscle stiffness Alopecia Obesity     class
# 0              No              Yes      Yes     Yes  Positive
# 1             Yes               No      Yes      No  Positive
# 2              No              Yes      Yes      No  Positive
# 3              No               No       No      No  Positive
# 4             Yes              Yes      Yes     Yes  Positive

# %%
#Check data shape
print("Data shape:")
print("Rows:")
print(data.shape[0] * 10)
print("Number of columns:")
print(data.shape[1])
print("\n")
#Check summary info
print("Data summary:")
print(data.info())
print("\n")
# Out:
# Data shape:
# Rows:
# 5200
# Number of columns:
# 17
#
#
# Data summary:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 520 entries, 0 to 519
# Data columns (total 17 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Age                 520 non-null    int64
#  1   Gender              520 non-null    object
#  2   Polyuria            520 non-null    object
#  3   Polydipsia          520 non-null    object
#  4   sudden weight loss  520 non-null    object
#  5   weakness            520 non-null    object
#  6   Polyphagia          520 non-null    object
#  7   Genital thrush      520 non-null    object
#  8   visual blurring     520 non-null    object
#  9   Itching             520 non-null    object
#  10  Irritability        520 non-null    object
#  11  delayed healing     520 non-null    object
#  12  partial paresis     520 non-null    object
#  13  muscle stiffness    520 non-null    object
#  14  Alopecia            520 non-null    object
#  15  Obesity             520 non-null    object
#  16  class               520 non-null    object
# dtypes: int64(1), object(16)
# memory usage: 69.2+ KB
# None

# %%
data.describe()
# Out:
#               Age
# count  520.000000
# mean    48.028846
# std     12.151466
# min     16.000000
# 25%     39.000000
# 50%     47.500000
# 75%     57.000000
# max     90.000000

# %%
data.describe(include="O")
# Out:
#        Gender Polyuria Polydipsia sudden weight loss weakness Polyphagia  \
# count     520      520        520                520      520        520
# unique      2        2          2                  2        2          2
# top      Male       No         No                 No      Yes         No
# freq      328      262        287                303      305        283
#
#        Genital thrush visual blurring Itching Irritability delayed healing  \
# count             520             520     520          520             520
# unique              2               2       2            2               2
# top                No              No      No           No              No
# freq              404             287     267          394             281
#
#        partial paresis muscle stiffness Alopecia Obesity     class
# count              520              520      520     520       520
# unique               2                2        2       2         2
# top                 No               No       No      No  Positive
# freq               296              325      341     432       320

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 520 entries, 0 to 519
# Data columns (total 17 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Age                 520 non-null    int64
#  1   Gender              520 non-null    object
#  2   Polyuria            520 non-null    object
#  3   Polydipsia          520 non-null    object
#  4   sudden weight loss  520 non-null    object
#  5   weakness            520 non-null    object
#  6   Polyphagia          520 non-null    object
#  7   Genital thrush      520 non-null    object
#  8   visual blurring     520 non-null    object
#  9   Itching             520 non-null    object
#  10  Irritability        520 non-null    object
#  11  delayed healing     520 non-null    object
#  12  partial paresis     520 non-null    object
#  13  muscle stiffness    520 non-null    object
#  14  Alopecia            520 non-null    object
#  15  Obesity             520 non-null    object
#  16  class               520 non-null    object
# dtypes: int64(1), object(16)
# memory usage: 69.2+ KB

# %%
data.columns = map(str.lower, data.columns)

plt.figure(figsize=(10, 6))
sns.histplot(data["age"], bins=10, color="orange", kde=True)
plt.title("Age Distribution")
plt.xlabel("Age")
plt.ylabel("Frequency")
plt.show()

# %%
for col in data:
    plt.figure(figsize=(17, 7))
    sns.countplot(x=col, data=data, palette="viridis")
    plt.title(f"Value Count for each Class in {col}")
    plt.show()
# Out:
# <ipython-input-8-8c4d5844a131>:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x=col, data=data, palette="viridis")
# <ipython-input-8-8c4d5844a131>:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x=col, data=data, palette="viridis")
# <ipython-input-8-8c4d5844a131>:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x=col, data=data, palette="viridis")
# <ipython-input-8-8c4d5844a131>:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x=col, data=data, palette="viridis")
# <ipython-input-8-8c4d5844a131>:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x=col, data=data, palette="viridis")
# <ipython-input-8-8c4d5844a131>:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x=col, data=data, palette="viridis")
# <ipython-input-8-8c4d5844a131>:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x=col, data=data, palette="viridis")
# <ipython-input-8-8c4d5844a131>:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x=col, data=data, palette="viridis")
# <ipython-input-8-8c4d5844a131>:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x=col, data=data, palette="viridis")
# <ipython-input-8-8c4d5844a131>:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x=col, data=data, palette="viridis")
# <ipython-input-8-8c4d5844a131>:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x=col, data=data, palette="viridis")
# <ipython-input-8-8c4d5844a131>:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x=col, data=data, palette="viridis")
# <ipython-input-8-8c4d5844a131>:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x=col, data=data, palette="viridis")
# <ipython-input-8-8c4d5844a131>:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x=col, data=data, palette="viridis")
# <ipython-input-8-8c4d5844a131>:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x=col, data=data, palette="viridis")
# <ipython-input-8-8c4d5844a131>:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x=col, data=data, palette="viridis")
# <ipython-input-8-8c4d5844a131>:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x=col, data=data, palette="viridis")

# %%
mapping = {"Yes":1, "No":0, "Negative":0, "Positive":1}

# %%
for col in data:
    if col != "gender":
        data[col] = data[col].apply(mapping.get)

# %%
data.sample(5)
# Out:
#       age gender  polyuria  polydipsia  sudden weight loss  weakness  \
# 211  None   Male         0           0                   0         1
# 441  None   Male         1           0                   0         0
# 324  None   Male         0           0                   0         0
# 232  None   Male         0           1                   0         1
# 158  None   Male         1           0                   1         1
#
#      polyphagia  genital thrush  visual blurring  itching  irritability  \
# 211           0               0                0        0             1
# 441           0               0                1        0             0
# 324           0               0                0        0             0
# 232           1               0                1        1             0
# 158           0               1                0        1             1
#
#      delayed healing  partial paresis  muscle stiffness  alopecia  obesity  \
# 211                0                0                 0         0        0
# 441                0                1                 0         1        0
# 324                0                0                 0         0        0
# 232                1                0                 1         1        0
# 158                0                0                 0         1        0
#
#      class
# 211      0
# 441      1
# 324      0
# 232      0
# 158      1

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score
from sklearn.pipeline import Pipeline
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import StandardScaler
import pandas as pd

# %%
X, y = data.drop(columns=["class"]), data["class"]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=20)

# %%
X_train.head()
# Out:
#       age  gender  polyuria  polydipsia  sudden weight loss  weakness  \
# 336  None    Male         0           0                   0         0
# 204  None    Male         0           0                   0         0
# 81   None  Female         0           0                   1         1
# 129  None    Male         1           1                   1         1
# 9    None    Male         0           1                   1         1
#
#      polyphagia  genital thrush  visual blurring  itching  irritability  \
# 336           0               0                0        0             0
# 204           0               0                0        0             0
# 81            1               0                0        0             0
# 129           0               0                0        1             0
# 9             1               0                1        1             1
#
#      delayed healing  partial paresis  muscle stiffness  alopecia  obesity
# 336                0                0                 0         1        0
# 204                0                0                 0         0        0
# 81                 0                0                 1         0        0
# 129                0                1                 0         1        0
# 9                  0                0                 0         1        0

# %%
X_train.shape
# Out:
# (416, 16)

# %%
X_test.head()
# Out:
#       age  gender  polyuria  polydipsia  sudden weight loss  weakness  \
# 31   None    Male         1           1                   1         1
# 29   None    Male         1           1                   1         1
# 449  None  Female         1           1                   1         1
# 367  None  Female         1           1                   1         1
# 189  None  Female         1           0                   1         1
#
#      polyphagia  genital thrush  visual blurring  itching  irritability  \
# 31            1               1                1        1             1
# 29            1               0                1        0             1
# 449           0               0                1        1             0
# 367           0               0                1        0             0
# 189           1               1                1        1             0
#
#      delayed healing  partial paresis  muscle stiffness  alopecia  obesity
# 31                 0                0                 0         0        1
# 29                 0                1                 0         1        0
# 449                0                1                 1         0        0
# 367                1                1                 1         0        0
# 189                1                0                 0         1        0

# %%
X_test.shape
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-cf290153e199> in <cell line: 1>()
# ----> 1 X_test.shape
#
# NameError: name 'X_test' is not defined

# %%
y_train
# Out:
# 336    0
# 204    0
# 81     1
# 129    1
# 9      1
#       ..
# 218    0
# 223    0
# 271    1
# 474    0
# 355    0
# Name: class, Length: 416, dtype: int64

# %%
y_train.value_counts()
# Out:
# class
# 1    251
# 0    165
# Name: count, dtype: int64

# %%
ohe_col = ["gender"]

X_train_encoded = pd.concat([X_train.drop(ohe_col, axis=1), pd.get_dummies(X_train[ohe_col], drop_first=True)], axis=1)
X_test_encoded = pd.concat([X_test.drop(ohe_col, axis=1), pd.get_dummies(X_test[ohe_col], drop_first=True)], axis=1)

X_train_encoded.head()
# Out:
#       age  polyuria  polydipsia  sudden weight loss  weakness  polyphagia  \
# 336  None         0           0                   0         0           0
# 204  None         0           0                   0         0           0
# 81   None         0           0                   1         1           1
# 129  None         1           1                   1         1           0
# 9    None         0           1                   1         1           1
#
#      genital thrush  visual blurring  itching  irritability  delayed healing  \
# 336               0                0        0             0                0
# 204               0                0        0             0                0
# 81                0                0        0             0                0
# 129               0                0        1             0                0
# 9                 0                1        1             1                0
#
#      partial paresis  muscle stiffness  alopecia  obesity  gender_Male
# 336                0                 0         1        0         True
# 204                0                 0         0        0         True
# 81                 0                 1         0        0        False
# 129                1                 0         1        0         True
# 9                  0                 0         1        0         True

# %%
X_test_encoded.head()
# Out:
#       age  polyuria  polydipsia  sudden weight loss  weakness  polyphagia  \
# 31   None         1           1                   1         1           1
# 29   None         1           1                   1         1           1
# 449  None         1           1                   1         1           0
# 367  None         1           1                   1         1           0
# 189  None         1           0                   1         1           1
#
#      genital thrush  visual blurring  itching  irritability  delayed healing  \
# 31                1                1        1             1                0
# 29                0                1        0             1                0
# 449               0                1        1             0                0
# 367               0                1        0             0                1
# 189               1                1        1             0                1
#
#      partial paresis  muscle stiffness  alopecia  obesity  gender_Male
# 31                 0                 0         0        1         True
# 29                 1                 0         1        0         True
# 449                1                 1         0        0        False
# 367                1                 1         0        0        False
# 189                0                 0         1        0        False

# %%
X_enc_df = pd.concat([X_train_encoded, X_test_encoded])
X_enc_df.head()
# Out:
#       age  polyuria  polydipsia  sudden weight loss  weakness  polyphagia  \
# 336  None         0           0                   0         0           0
# 204  None         0           0                   0         0           0
# 81   None         0           0                   1         1           1
# 129  None         1           1                   1         1           0
# 9    None         0           1                   1         1           1
#
#      genital thrush  visual blurring  itching  irritability  delayed healing  \
# 336               0                0        0             0                0
# 204               0                0        0             0                0
# 81                0                0        0             0                0
# 129               0                0        1             0                0
# 9                 0                1        1             1                0
#
#      partial paresis  muscle stiffness  alopecia  obesity  gender_Male
# 336                0                 0         1        0         True
# 204                0                 0         0        0         True
# 81                 0                 1         0        0        False
# 129                1                 0         1        0         True
# 9                  0                 0         1        0         True

# %% [markdown]
# Logistic Regression

# %%
X_train_encoded_clean = X_train_encoded.dropna()
y_train_clean = y_train[X_train_encoded_clean.index]

# %%
imputer = SimpleImputer(strategy='mean')  # or 'median', 'most_frequent'
X_train_encoded_imputed = imputer.fit_transform(X_train_encoded)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/impute/_base.py:598: UserWarning: Skipping features without any observed values: ['age']. At least one non-missing value is needed for imputation with strategy='mean'.
#   warnings.warn(

# %%
pipeline = Pipeline([
    ('imputer', SimpleImputer(strategy='mean')),  # Use mean imputation, change strategy as needed
    ('lr', LogisticRegression(max_iter=1000))
])
pipeline.fit(X_train_encoded, y_train)
pred = pipeline.predict(X_test_encoded)
accuracy = accuracy_score(y_test, pred)
print ("The accuracy is : " , accuracy)
# Out:
# The accuracy is :  0.9326923076923077
# /usr/local/lib/python3.10/dist-packages/sklearn/impute/_base.py:598: UserWarning: Skipping features without any observed values: ['age']. At least one non-missing value is needed for imputation with strategy='mean'.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/impute/_base.py:598: UserWarning: Skipping features without any observed values: ['age']. At least one non-missing value is needed for imputation with strategy='mean'.
#   warnings.warn(

# %% [markdown]
# LOGISTIC REGRESSION

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score
import pandas as pd

# Identify numeric and categorical columns
numeric_features = X_train_encoded.select_dtypes(include=['int64', 'float64']).columns
categorical_features = X_train_encoded.select_dtypes(include=['object']).columns

# Preprocessor for numeric and categorical columns
preprocessor = ColumnTransformer(
    transformers=[
        ('num', Pipeline([
            ('imputer', SimpleImputer(strategy='mean')),
            ('scaler', StandardScaler())
        ]), numeric_features),

        ('cat', Pipeline([
            ('imputer', SimpleImputer(strategy='most_frequent')),
            ('encoder', OneHotEncoder(handle_unknown='ignore'))
        ]), categorical_features)
    ]
)

# Full pipeline with logistic regression
pipeline = Pipeline([
    ('preprocessor', preprocessor),
    ('classifier', LogisticRegression(max_iter=1000))
])

# Fit the model
pipeline.fit(X_train_encoded, y_train)

# Make predictions
pred = pipeline.predict(X_test_encoded)

# Calculate accuracy
accuracy = accuracy_score(y_test, pred)
print("The accuracy is:", accuracy)
# Out:
# The accuracy is: 0.8942307692307693

# %% [markdown]
# SUPPORT VECTOR MACHINE

# %%
from sklearn.svm import SVC

pipeline_svm = Pipeline([
    ('preprocessor', preprocessor),
    ('classifier', SVC())
])

pipeline_svm.fit(X_train_encoded, y_train)
pred_svm = pipeline_svm.predict(X_test_encoded)
accuracy_svm = accuracy_score(y_test, pred_svm)
print("SVM Accuracy:", accuracy_svm)
# Out:
# SVM Accuracy: 0.9615384615384616

# %% [markdown]
# K NEAREST NEIGHBOR

# %%
from sklearn.neighbors import KNeighborsClassifier

pipeline_knn = Pipeline([
    ('preprocessor', preprocessor),
    ('classifier', KNeighborsClassifier())
])

pipeline_knn.fit(X_train_encoded, y_train)
pred_knn = pipeline_knn.predict(X_test_encoded)
accuracy_knn = accuracy_score(y_test, pred_knn)
print("K-Nearest Neighbors Accuracy:", accuracy_knn)
# Out:
# K-Nearest Neighbors Accuracy: 0.9519230769230769

# %% [markdown]
# NAIVE BAYES

# %%
from sklearn.naive_bayes import GaussianNB

pipeline_nb = Pipeline([
    ('preprocessor', preprocessor),
    ('classifier', GaussianNB())
])

pipeline_nb.fit(X_train_encoded, y_train)
pred_nb = pipeline_nb.predict(X_test_encoded)
accuracy_nb = accuracy_score(y_test, pred_nb)
print("Naive Bayes Accuracy:", accuracy_nb)
# Out:
# Naive Bayes Accuracy: 0.8846153846153846

# %% [markdown]
# RANDOM FOREST

# %%
from sklearn.ensemble import RandomForestClassifier

pipeline_rf = Pipeline([
    ('preprocessor', preprocessor),
    ('classifier', RandomForestClassifier())
])

pipeline_rf.fit(X_train_encoded, y_train)
pred_rf = pipeline_rf.predict(X_test_encoded)
accuracy_rf = accuracy_score(y_test, pred_rf)
print("Random Forest Accuracy:", accuracy_rf)
# Out:
# Random Forest Accuracy: 0.9807692307692307

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.ensemble import RandomForestClassifier
from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.metrics import accuracy_score

# Identify numeric and categorical columns
numeric_features = X_train_encoded.select_dtypes(include=['int64', 'float64']).columns
categorical_features = X_train_encoded.select_dtypes(include=['object']).columns

# Preprocessor for numeric and categorical columns
preprocessor = ColumnTransformer(
    transformers=[
        ('num', Pipeline([
            ('imputer', SimpleImputer(strategy='mean')),
            ('scaler', StandardScaler())
        ]), numeric_features),

        ('cat', Pipeline([
            ('imputer', SimpleImputer(strategy='most_frequent')),
            ('encoder', OneHotEncoder(handle_unknown='ignore'))
        ]), categorical_features)
    ]
)

# Define classifiers
classifiers = {
    "Logistic Regression": LogisticRegression(max_iter=1000),
    "SVM": SVC(),
    "K-Nearest Neighbors": KNeighborsClassifier(),
    "Naive Bayes": GaussianNB(),
    "Random Forest": RandomForestClassifier()
}

# Store results
results = {}

# Iterate over classifiers
for name, clf in classifiers.items():
    # Create pipeline
    pipeline = Pipeline([
        ('preprocessor', preprocessor),
        ('classifier', clf)
    ])

    # Train and predict
    pipeline.fit(X_train_encoded, y_train)
    pred = pipeline.predict(X_test_encoded)

    # Calculate accuracy and store results
    accuracy = accuracy_score(y_test, pred)
    results[name] = accuracy

# Print all results together
print("Accuracy Scores:")
for name, score in results.items():
    print(f"{name}: {score:.4f}")
# Out:
# Accuracy Scores:
# Logistic Regression: 0.8942
# SVM: 0.9615
# K-Nearest Neighbors: 0.9519
# Naive Bayes: 0.8846
# Random Forest: 0.9615
